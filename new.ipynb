# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeshbhatta495/Nepali-STT-Model/blob/main/new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sounddevice as sd
import soundfile as sf

fs = 16000
seconds = 6

print("Speak now...")
audio = sd.rec(int(seconds * fs), samplerate=fs, channels=1)
sd.wait()

sf.write("input.wav", audio, fs)
print("Audio recorded and saved as input.wav")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libasound2-dev libjack-dev libjack0 libportaudio2 libportaudiocpp0
# Suggested packages:
#   libasound2-doc jackd1 portaudio19-doc
# The following packages will be REMOVED:
#   libjack-jackd2-0
# The following NEW packages will be installed:
#   libasound2-dev libjack-dev libjack0 libportaudio2 libportaudiocpp0
#   portaudio19-dev
# 0 upgraded, 6 newly installed, 1 to remove and 2 not upgraded.
# Need to get 596 kB of archives.
# After this operation, 3,178 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjack0 amd64 1:0.125.0-3build2 [93.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libasound2-dev amd64 1.2.6.1-1ubuntu1 [110 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjack-dev amd64 1:0.125.0-3build2 [206 kB]
# ...

# %%
import whisper

model = whisper.load_model("small")
result = model.transcribe("input.wav", language="ne")

text = result["text"]
print(text)
with open("output.txt", "w") as f:
    f.write(text)
print("Transcription saved as output.txt")
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  नागरित्ते को पारम
# Transcription saved as output.txt

# %%
normalization_map = {
    "बिजुलि": "बिजुली",
    "नागरीकता": "नागरिकता"
}

def normalize(text):
    for wrong, correct in normalization_map.items():
        text = text.replace(wrong, correct)
    return text

text = normalize(text)

# %%
from google.colab import files
import soundfile as sf
import os

# Upload an audio file
uploaded = files.upload()

# Assuming only one file is uploaded, get its name
filename = list(uploaded.keys())[0]

# Load the audio file and save it as input.wav
data, samplerate = sf.read(filename)
sf.write('input.wav', data, samplerate)

print(f"Uploaded audio '{filename}' saved as 'input.wav'")

# You can now proceed to transcribe 'input.wav'
# Out:
#      <input type="file" id="files-02a3fe66-dee5-4625-895d-53165421a81c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02a3fe66-dee5-4625-895d-53165421a81c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Task
# Update the `normalization_map` to include the correction for 'नागरित्ते को पारम' to 'नागरिकता ko Faram (form)' and then apply this normalization to the transcribed text. After that, prepare to demonstrate word embeddings for 'social service' terms by installing `gensim`, loading a pre-trained model, and retrieving word vectors.

# %% [markdown]
# ## Correct Nepali Transcription
#
# ### Subtask:
# Update the existing `normalization_map` to transform 'नागरित्ते को पारम' into 'नागरिकता ko Faram (form)', ensuring accurate representation of the desired text.

# %% [markdown]
# **Reasoning**:
# The subtask requires updating the `normalization_map` with a new entry and then applying this updated map to the `text` variable using the `normalize` function. This will ensure the transcription is corrected as per the instructions.

# %%
normalization_map = {
    "बिजुलि": "बिजुली",
    "नागरीकता": "नागरिकता",
    " नागरित्ते को पारम": "नागरिकता फारम (फार्म)"
}

def normalize(text):
    for wrong, correct in normalization_map.items():
        text = text.replace(wrong, correct)
    return text

text = normalize(text)
print(text)
# Out:
# नागरिकता ko Faram (form)

# %% [markdown]
# ## Prepare Word Embeddings for Social Service
#
# ### Subtask:
# Install necessary libraries like `gensim` and demonstrate how to load a pre-trained word embedding model. Then, showcase how to retrieve word vectors for specific terms related to 'social service' and explain how to apply this approach with domain-specific text.

# %% [markdown]
# **Reasoning**:
# The first step is to install the `gensim` library as requested in the instructions to prepare for word embedding tasks.

# %%
get_ipython().system('pip install gensim')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 23.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Reasoning**:
# Now that `gensim` is installed, I will import the necessary `api` module, load a pre-trained Word2Vec model, and then demonstrate retrieving word vectors and finding similar words for 'social' and 'service' as instructed.

# %%
import gensim.downloader as api

print("Downloading word2vec-google-news-300 model (this may take a while)...")
word_vectors = api.load("word2vec-google-news-300")
print("Model downloaded successfully.")

# Access and print word vectors for 'social' and 'service'
print("\nWord vector for 'social':")
print(word_vectors['social'])

print("\nWord vector for 'service':")
print(word_vectors['service'])

# Find and display words most similar to 'social' and 'service'
print("\nWords most similar to 'social':")
print(word_vectors.most_similar('social'))

print("\nWords most similar to 'service':")
print(word_vectors.most_similar('service'))
# Out:
# ...
# [==================================----------------] 70.0% 1163.6/1662.8MB downloaded
